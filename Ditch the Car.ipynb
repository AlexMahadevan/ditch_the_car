# %% [markdown]
# # ‘Ditch the Car’ Analysis
#
# <p>Data courtesy of [WalkScore](https://www.walkscore.com)

# %%
import pandas as pd

# %%
ACS_2015 = pd.read_csv("/Users/alexmahadevan/Desktop/Projects/Data/county data/economics/economics_county.csv")

# %%
ACS_2010 = pd.read_csv("/Users/alexmahadevan/Desktop/ACS_10_5YR_DP03/ACS_10_5YR_DP03_with_ann.csv")

# %%
walkers_2015 = ACS_2015[['GEO.display-label' , 'HC03_VC30' , 'HC03_VC31' , 'HC03_VC32' ]]

# %%
walkers_2010 = ACS_2010[['GEO.display-label' , 'HC03_VC31' , 'HC03_VC32' , 'HC03_VC33']]

# %%
walkers_2015.to_csv("/Users/alexmahadevan/Code/ditch_the_car/walk_transit_2015.csv")

# %%
walkers_2010.to_csv("/Users/alexmahadevan/Code/ditch_the_car/walk_transit_2010.csv")

# %%
df_walk = pd.read_csv("/Users/alexmahadevan/Desktop/Projects/Affordable Walkability/Walk_score_data.csv")

# %%
df_walk.head()
# Out:
#            City State  Walk Score Transit Score Bike Score Population
# 0      New York    NY        89.2          84.1       65.1  8,175,133
# 1   Los Angeles    CA        67.4          51.3         56  3,792,621
# 2       Chicago    IL        77.8          64.7       70.2  2,695,598
# 3       Houston    TX        48.7          36.8       49.3  2,099,451
# 4  Philadelphia    PA        79.0          66.8       67.5  1,526,006

# %%
df_cities = pd.read_csv("/Users/alexmahadevan/Desktop/Projects/Raise a Family/locations.csv")

# %%
df_cities.head()
# Out:
#    Unnamed: 0   id          name                      county state_code  \
# 0           0    1          Adak  Aleutians West Census Area         AK
# 1           1   21          Atka  Aleutians West Census Area         AK
# 2           2   24  Attu Station  Aleutians West Census Area         AK
# 3           3  225      Nikolski  Aleutians West Census Area         AK
# 4           4  304    St. George  Aleutians West Census Area         AK
#
#     state zip_codes  type  latitude  longitude  \
# 0  Alaska     99546  City  51.88000 -176.65806
# 1  Alaska     99547  City  52.19611 -174.20056
# 2  Alaska     96950   CDP  52.88025  173.25608
# 3  Alaska     99638   CDP  52.93806 -168.86778
# 4  Alaska     99591  City  56.60000 -169.54167
#
#                      ...                     RNETMIG2015  RNETMIG2016  \
# 0                    ...                       -9.375814   -21.429826
# 1                    ...                       -9.375814   -21.429826
# ...

# %%
df_walk['CITIES'] = df_walk['City'] + ", " + df_walk['State']

# %%
df_walk.head()
# Out:
#            City State  Walk Score Transit Score Bike Score Population  \
# 0      New York    NY        89.2          84.1       65.1  8,175,133
# 1   Los Angeles    CA        67.4          51.3         56  3,792,621
# 2       Chicago    IL        77.8          64.7       70.2  2,695,598
# 3       Houston    TX        48.7          36.8       49.3  2,099,451
# 4  Philadelphia    PA        79.0          66.8       67.5  1,526,006
#
#              CITIES
# 0      New York, NY
# 1   Los Angeles, CA
# 2       Chicago, IL
# 3       Houston, TX
# 4  Philadelphia, PA

# %%
df_cities['CITIES'] = df_cities['name'] + ", " + df_cities['state_code']

# %%
df_merged = pd.merge(df_walk, df_cities, on='CITIES' )

# %%
df_merged.head(3)
# Out:
#            City State  Walk Score Transit Score Bike Score Population  \
# 0   Los Angeles    CA        67.4          51.3         56  3,792,621
# 1  Philadelphia    PA        79.0          66.8       67.5  1,526,006
# 2       Phoenix    AZ        40.8          32.2       54.3  1,445,632
#
#              CITIES  Unnamed: 0     id          name  \
# 0   Los Angeles, CA        2006   2726   Los Angeles
# 1  Philadelphia, PA       36193  36037  Philadelphia
# 2       Phoenix, AZ        1436   1750       Phoenix
#
#                      ...                     RNETMIG2015 RNETMIG2016  \
# 0                    ...                       -1.853127   -3.215874
# 1                    ...                       -1.096119   -2.510824
# 2                    ...                       12.147374   12.701802
#
#   AVG_NETMIG POP_CHANGE BIRTHS_PER_CAPITA            CTYNAME_y  \
# 0  -1.467857   0.031799          0.012673   Los Angeles County
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 0 to 89
# Columns: 150 entries, City to Med_HH_Income_Percent_of_State_Total_2015
# dtypes: float64(44), int64(85), object(21)
# memory usage: 106.2+ KB

# %%
df_merged.sort_values("Med_HH_Income_Percent_of_State_Total_2015", ascending=False)
# Out:
#                  City State  Walk Score Transit Score Bike Score Population  \
# 4            San Jose    CA        50.5            41       56.9    945,942
# 85          Arlington    VA        68.9            58         71    207,627
# 6       San Francisco    CA        86.0          80.4       75.1    805,235
# 13            Seattle    WA        73.1            57         63    608,660
# 28            Oakland    CA        72.0          55.1       60.9    390,724
# 78            Fremont    CA        44.2          36.4       61.1    214,089
# 79             Irvine    CA        43.5          27.4       69.7    212,375
# 35            Anaheim    CA        54.5          35.4       51.9    336,265
# 37          Santa Ana    CA        66.1            46       57.1    324,528
# 87         Boise City    ID        40.2            --       62.9    205,671
# 7           Charlotte    NC        25.9            --       36.1    731,424
# ...
